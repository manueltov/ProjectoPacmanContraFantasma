# %%
import testing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-668bdf12404a> in <module>
# ----> 1 import testing
#
# ~\OneDrive - Universidade de Lisboa\1-ESTUDOS\IIA\PROJETO\ProjectoPacmanContraFantasma\testing.py in <module>
#      64     melhores_linha = extrai_melhor_params(matriz)
#      65
# ---> 66 optimiza()
#
# ~\OneDrive - Universidade de Lisboa\1-ESTUDOS\IIA\PROJETO\ProjectoPacmanContraFantasma\testing.py in optimiza()
#      61
#      62 def optimiza():
# ---> 63     matriz = cria_matriz()
#      64     melhores_linha = extrai_melhor_params(matriz)
#      65
#
# ~\OneDrive - Universidade de Lisboa\1-ESTUDOS\IIA\PROJETO\ProjectoPacmanContraFantasma\testing.py in cria_matriz()
#      37         p3 = randint(-100,100)
#      38
# ---> 39         sum = corre_pac(p1, p2, p3)
#      40
#      41         matriz[i][0] = sum
#
# ...
